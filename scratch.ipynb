# %%
from shrec.models import RecurrenceManifold
from benchmarks.dynamical_systems import load_data

# %%
X, y_true = load_data() # shape (n_timepoints, n_series)
model = RecurrenceManifold()
y_recon = model.fit_predict(X)
# Out:
# /Users/Neil.Anthony/Developer/nranthony/shrec/src/shrec/models/models.py:297: UserWarning: 13 Constant time series detected. Skipping these datasets.
#   warnings.warn(f"{np.sum(sel_inds)} Constant time series detected. "

# %%
import seaborn as sns
sns.lineplot(y_recon)
# Out:
# <Axes: >
